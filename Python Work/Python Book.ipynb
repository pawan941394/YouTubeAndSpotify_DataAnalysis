# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =  pd.read_csv("C:/Users/user/Desktop/Master's in Data Science and AI/Projects/Python , Tableau, SQL, Power BI/YouTube and Spotify Data Analysis/DataBase/Spotify_Youtube.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %%
df.shape
# Out:
# (20718, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %%
df['Artist'].nunique()
# Out:
# 2079

# %%
duplicate_rows_subset = df[df.duplicated(subset = ['Artist','Track'])]

# %%
duplicate_rows_subset
# Out:
#        Unnamed: 0              Artist  \
# 773           773     Whitney Houston
# 1582         1582           Scorpions
# 1583         1583           Scorpions
# 1625         1625  Earth, Wind & Fire
# 1695         1695              Shaggy
# ...           ...                 ...
# 17603       17603             Seafret
# 18133       18133      Shiloh Dynasty
# 19010       19010            Soolking
# 19074       19074               Beret
# 20595       20595          João Gomes
#
#                                              Url_spotify             Track  \
# 773    https://open.spotify.com/artist/6XpaIBNiVzIetE...   How Will I Know
# 1582   https://open.spotify.com/artist/27T030eWyCQRmD...  Still Loving You
# 1583   https://open.spotify.com/artist/27T030eWyCQRmD...   No One Like You
# 1625   https://open.spotify.com/artist/4QQgXkCYTt3BlE...           Fantasy
# 1695   https://open.spotify.com/artist/5EvFsr3kj42KNv...      It Wasn't Me
# ...

# %% [markdown]
# 82 duplicate rows Use Drop_duplicates to remove

# %%
df.drop_duplicates(subset=['Artist','Track'], inplace = True)

# %%
dup = df[df.duplicated(subset = ['Track','Album'])]
dup
# Out:
#        Unnamed: 0          Artist  \
# 155           155         Shakira
# 248           248       Lil Wayne
# 296           296          Tiësto
# 312           312           JAY-Z
# 333           333      Kanye West
# ...           ...             ...
# 20673       20673  Grupo Frontera
# 20675       20675  Grupo Frontera
# 20679       20679  Grupo Frontera
# 20682       20682       Jung Kook
# 20683       20683       Jung Kook
#
#                                              Url_spotify  \
# 155    https://open.spotify.com/artist/0EmeFodog0BfCg...
# 248    https://open.spotify.com/artist/55Aa2cqylxrFIX...
# 296    https://open.spotify.com/artist/2o5jDhtHVPhrJd...
# 312    https://open.spotify.com/artist/3nFkdlSjzX9mRT...
# 333    https://open.spotify.com/artist/5K4W6rqBFWDnAN...
# ...                                                  ...
# 20673  https://open.spotify.com/artist/6XkjpgcEsYab50...
# 20675  https://open.spotify.com/artist/6XkjpgcEsYab50...
# ...

# %%
df.shape
# Out:
# (20636, 28)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %% [markdown]
# Now we remove the redundant columns

# %%
df.drop(['Url_spotify','Url_youtube','Description', 'Title','Unnamed: 0'], axis =1 , inplace = True)

# %%
df.columns
# Out:
# Index(['Artist', 'Track', 'Album', 'Album_type', 'Uri', 'Danceability',
#        'Energy', 'Key', 'Loudness', 'Speechiness', 'Acousticness',
#        'Instrumentalness', 'Liveness', 'Valence', 'Tempo', 'Duration_ms',
#        'Channel', 'Views', 'Likes', 'Comments', 'Licensed', 'official_video',
#        'Stream'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Danceability        Energy           Key      Loudness   Speechiness  \
# count  20634.000000  20634.000000  20634.000000  20634.000000  20634.000000
# mean       0.619679      0.635300      5.297761     -7.666687      0.096519
# std        0.165274      0.214101      3.576368      4.632325      0.112095
# min        0.000000      0.000020      0.000000    -46.251000      0.000000
# 25%        0.518000      0.507000      2.000000     -8.844000      0.035700
# 50%        0.637000      0.666000      5.000000     -6.531000      0.050500
# 75%        0.740000      0.798000      8.000000     -4.929250      0.103000
# max        0.975000      1.000000     11.000000      0.920000      0.964000
#
#        Acousticness  Instrumentalness      Liveness       Valence  \
# count  20634.000000      20634.000000  20634.000000  20634.000000
# mean       0.291455          0.055902      0.193364      0.529677
# std        0.286251          0.193180      0.168340      0.245405
# ...

# %%
df['Views'].isnull().sum()
# Out:
# 469

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20636 entries, 0 to 20717
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20636 non-null  object
#  1   Track             20636 non-null  object
#  2   Album             20636 non-null  object
#  3   Album_type        20636 non-null  object
#  4   Uri               20636 non-null  object
#  5   Danceability      20634 non-null  float64
#  6   Energy            20634 non-null  float64
#  7   Key               20634 non-null  float64
#  8   Loudness          20634 non-null  float64
#  9   Speechiness       20634 non-null  float64
#  10  Acousticness      20634 non-null  float64
#  11  Instrumentalness  20634 non-null  float64
#  12  Liveness          20634 non-null  float64
#  13  Valence           20634 non-null  float64
#  14  Tempo             20634 non-null  float64
#  15  Duration_ms       20634 non-null  float64
# ...

# %%
df['Licensed'] = df['Licensed'].astype('bool')

# %%
df['official_video'] = df['official_video'].astype('bool')

# %%
df['Duration_minute'] = df['Duration_ms'] / 6000 
df.drop(columns=['Duration_ms'], inplace = True)

# %% [markdown]
#    # Hist Ploating

# %% [raw]
# 1. Box Plot for Danceablity

# %%
sns.histplot(df['Danceability'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Danceability")
plt.show()

# %% [markdown]
# 2. Box Plot for Energy

# %%
sns.histplot(df['Energy'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Energy")
plt.show()

# %% [markdown]
# 3. Box Plot for Key

# %%
sns.histplot(df['Key'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Key")
plt.show()

# %% [markdown]
# 4. Box Plot for Loudness

# %%
sns.histplot(df['Key'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Loudness")
plt.show()

# %% [markdown]
# 5. Box Plot for Speechiness

# %%
sns.histplot(df['Speechiness'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Speechiness")
plt.show()

# %% [markdown]
# 6. Box Plot for Acousticness

# %%
sns.histplot(df['Acousticness'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Acousticness")
plt.show()

# %% [markdown]
# 7. Box Plot for Liveness

# %%
sns.histplot(df['Liveness'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Liveness")
plt.show()

# %% [markdown]
# 8. Box Plot for Valence

# %%
sns.histplot(df['Valence'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Valence")
plt.show()

# %% [markdown]
# 9. Box Plot for Tempo

# %%
sns.histplot(df['Tempo'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Tempo")
plt.show()

# %% [markdown]
# 10. Box Plot for Duration_minute

# %%
sns.histplot(df['Duration_minute'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Duration_minute")
plt.show()

# %% [markdown]
# 11. Box Plot for Views

# %%
sns.histplot(df['Views'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Views")
plt.show()

# %% [markdown]
# 12. Box Plot for Likes

# %%
sns.histplot(df['Likes'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Likes")
plt.show()

# %% [markdown]
# 13. Box Plot for Comments

# %%
sns.histplot(df['Comments'], kde = True, bins = 20,color='red', edgecolor='blue')
plt.title("Box Plot for Comments")
plt.show()

# %% [markdown]
# # Box Ploting

# %%
plots_values = ['Danceability','Energy','Key','Loudness','Speechiness','Acousticness','Liveness','Valence','Tempo','Duration_minute','Views','Likes','Comments']

# %% [markdown]
# Ploting using for loop

# %%
for i in plots_values:
    sns.boxplot(data= df,y=df[i])
    plt.title(f"Boxplot for {i}")
    plt.show()

# %% [markdown]
# Ploting for Stream

# %%
sns.histplot(df['Stream'], kde=True, bins=20)
plt.title('Histogram for Stream')
plt.show()

# %% [markdown]
# Count plot

# %%
sns.countplot(x='Album_type', data =df)
# Out:
# <Axes: xlabel='Album_type', ylabel='count'>

# %%
df.shape
# Out:
# (20636, 23)

# %%
df.isnull().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Channel             469
# Views               469
# Likes               540
# Comments            568
# Licensed              0
# official_video        0
# Stream              573
# Duration_minute       2
# dtype: int64

# %%
filling_Data = ['Danceability','Energy','Key','Loudness','Speechiness','Instrumentalness','Acousticness','Liveness','Valence','Tempo','Views','Likes',
                'Comments','Stream','Duration_minute'
            ]

# %%
for i in filling_Data:
    median_value =  df[i].median()
    df[i].fillna(median_value, inplace = True)

# %%
df.isnull().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          0
# Energy                0
# Key                   0
# Loudness              0
# Speechiness           0
# Acousticness          0
# Instrumentalness      0
# Liveness              0
# Valence               0
# Tempo                 0
# Channel             469
# Views                 0
# Likes                 0
# Comments              0
# Licensed              0
# official_video        0
# Stream                0
# Duration_minute       0
# dtype: int64

# %%
df['Key'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Creating Heat Map

# %%
plt.figure(figsize=(13,6))
sns.heatmap(df.corr(),annot= True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16152\3448278112.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot= True)
# <Axes: >

# %% [markdown]
# Views and Likes very correlated. Likes and comments too. Energy and Loudness. Stream and likes.

# %% [markdown]
# create a PIE chart

# %%
album_type_count = df['Album_type'].value_counts()
lables =  df['Album_type'].value_counts().index.tolist()
sizes =  df['Album_type'].value_counts().values.tolist()

# %%
labels = album_type_count.index.tolist()
sizes = album_type_count.values.tolist()
plt.pie(sizes, labels=labels, autopct='%1.1f%%',startangle=90)
plt.title('Album Types')
plt.legend(labels,loc='lower right' )
plt.show()

# %% [markdown]
# Analyzing songs by artist and views - youtube, stream - spotify

# %%
artist_group = df.groupby('Artist')[['Views','Stream']].sum()

# %%
artist_group.sort_values(['Views','Stream'],ascending=False).head(10)

# %% [markdown]
# Create two separate DataFrames for views and streams

# %%
df_views = df.groupby('Artist')['Views'].sum().sort_values(ascending = False)[:10]
df_stream = df.groupby('Artist')['Stream'].sum().sort_values(ascending = False)[:10]

# %%
fig,(ax1,ax2) = plt.subplots(1,2, figsize = (12,6))

ax1.set_title('Top 10 Artists  on YouTube')
ax1.set_xlabel('Artist')
ax1.set_ylabel('Views')
df_views.plot(kind='bar', ax=ax1)

ax2.set_title ('Top 10 Artist on Spotify')
ax2.set_xlabel('Artist')
ax2.set_ylabel('Streams')
df_stream.plot(kind='bar',ax = ax2)

fig.tight_layout()
plt.show()

# %% [markdown]
# Ed Sheeran was the most viewed artist, with 15 billion views on youtube. CoComelon and Katy Perry are the second and third most viewed artists with 14 billion and 13 billion views, respectively. Charlie Puth and Luis Fonsi complete the top five artists with 12 billion and 11 billion views, respectively.
#
# While on Spotify Post Malone was the most streamed artist, with 15 billion.Next Ed Shreeran is streamed about 14 billion. Dua Lipa and XXXTENTACION are the third and fourth most streamed artists with 13.5 billion and 13 billion, respectively. Yhe Weeknd is on fifth place by 13 billion streams.
#
# These figures highlight the popularity of these artists and their music on the different online platforms.

# %% [markdown]
# Analyzing Top 10 songs on the basis of views, comments and like

# %%
top10_views = df.nlargest(10,'Views')

# %%
top10_comments = df.nlargest(10,'Comments')

# %%
top10_likes = df.nlargest(10,'Likes')

# %%
# Top 10 songs with most views

top10_views.plot(kind='barh', x='Track', y='Views', title='Top 10 songs with most views')

# %%
# Top 10 songs with most comments
top10_views.plot(kind='barh', x='Track', y='Comments', title='Top 10 songs with most comments')

# %%
# Top 10 songs with most likes

top10_views.plot(kind='barh', x='Track', y='Likes', title='Top 10 songs with most likes')
plt.show()

# %% [markdown]
# Analyzing songs on the basis of Energy and Danceability

# %%
top_songs = df.sort_values('Stream', ascending = False).head(10)
top_songs[['Track', 'Energy','Danceability','Acousticness']]

# %% [markdown]
# Determining the top 10 artists on the Spotify platform whose songs have more likes.

# %%
df_artist =  df.set_index('Artist')
df_artist = df_artist[["Danceability","Views","Likes","Album_type"]]

# %%
df_artist_grouped = df_artist.groupby('Artist')['Likes'].sum().reset_index()

df_artist_sorted = df_artist_grouped.sort_values(by='Likes', ascending=False)

# %%
top_10_artists = df_artist_sorted.head(10)

# %%
sns.barplot(x='Likes', y='Artist', data=top_10_artists)

plt.xlabel('Number of Likes')
plt.ylabel('Artist')
plt.title('Number of Likes per Artist')

plt.show()

# %% [markdown]
# BTS and Blackpink are the most popular artist

# %% [markdown]
# Exploring compilation Releases by Artists: Identifying Top Performers Based on Likes

# %%
singles = df[df["Album_type"] == "compilation"]
grouped = singles.groupby("Artist").agg({"Views": "sum", "Likes": "sum"})
top_10_artists = grouped.sort_values("Likes", ascending=False).head(10)
print(top_10_artists)

# %% [markdown]
# In compilation ablum type Shakira is most viewed artist followed by Ellie Goulding and Dove Cameron

# %% [markdown]
# Identifying the top 10 channels based on views

# %%
df_channels = df.groupby("Channel")["Views"].sum().reset_index()
df_sort_channels = df_channels.sort_values("Views", ascending=False).head(10)
sns.set_style("whitegrid")
sns.barplot(x="Views", y="Channel", data=df_sort_channels, color='b')
sns.despine(left=True)
plt.title('Top Spotify Channels by Views')
plt.xlabel('Views')
plt.ylabel('Channel')
plt.show()

# %%
df.to_csv("C:/Users/user/Desktop/Master's in Data Science and AI/Projects/Python , Tableau, SQL, Power BI/YouTube and Spotify Data Analysis/Cleaned DataBase/Spotify_Youtube_cleaned.csv")

# %%
df.columns
